# %%
import pandas as pd

df = pd.read_csv("df_ligas_completo.csv")

# %%
df.head()
# Out:
#    fixture.id fixture.referee fixture.timezone               fixture.date  \
# 0     1048881       F. Zwayer              UTC  2023-08-18T18:30:00+00:00
# 1     1048886   F. Badstübner              UTC  2023-08-19T13:30:00+00:00
# 2     1048887    S. Jablonski              UTC  2023-08-19T13:30:00+00:00
# 3     1048884        F. Brych              UTC  2023-08-19T13:30:00+00:00
# 4     1048888     D. Schlager              UTC  2023-08-19T13:30:00+00:00
#
#    fixture.timestamp  fixture.periods.first  fixture.periods.second  \
# 0         1692383400             1692383400              1692387000
# 1         1692451800             1692451800              1692455400
# 2         1692451800             1692451800              1692455400
# 3         1692451800             1692451800              1692455400
# 4         1692451800             1692451800              1692455400
#
#    fixture.venue.id       fixture.venue.name fixture.venue.city  ...  \
# ...

# %%
df.columns
# Out:
# Index(['fixture.id', 'fixture.referee', 'fixture.timezone', 'fixture.date',
#        'fixture.timestamp', 'fixture.periods.first', 'fixture.periods.second',
#        'fixture.venue.id', 'fixture.venue.name', 'fixture.venue.city',
#        'fixture.status.long', 'fixture.status.short', 'fixture.status.elapsed',
#        'fixture.status.extra', 'league.id', 'league.name', 'league.country',
#        'league.logo', 'league.flag', 'league.season', 'league.round',
#        'league.standings', 'teams.home.id', 'teams.home.name',
#        'teams.home.logo', 'teams.home.winner', 'teams.away.id',
#        'teams.away.name', 'teams.away.logo', 'teams.away.winner', 'goals.home',
#        'goals.away', 'score.halftime.home', 'score.halftime.away',
#        'score.fulltime.home', 'score.fulltime.away', 'score.extratime.home',
#        'score.extratime.away', 'score.penalty.home', 'score.penalty.away'],
#       dtype='object')

# %%
remove = ["fixture.referee", # Nome do árbitro da partida
          "fixture.timezone", # Fuso horário do jogo
          "fixture.timestamp", # Data/hora em formato numérico (Unix)
          "fixture.periods.first", # Timestamp de início do 1º tempo
          "fixture.periods.second", # Timestamp de início do 2º tempo
          "fixture.status.long", # Descrição longa do status do jogo
          "fixture.status.elapsed", # Minutos jogados na partida
          "fixture.status.extra", # Detalhe extra do status (ex: prorrogação)
          "league.logo", # URL do logo da liga
          "league.flag", # URL da bandeira do país da liga
          "league.standings", # Tabela de classificação da liga
          "teams.home.logo", # URL do logo do time da cas
          "teams.home.winner", # Indicador de vitória (true/false) do time da casa
          "teams.away.logo", # URL do logo do time visitante
          "teams.away.winner", # Indicador de vitória (true/false) do time visitante
          "score.fulltime.home", # Placar do time da casa no tempo regulamentar
          "score.fulltime.away" # Placar do time visitante no tempo regulamentar
          ]

df.drop(columns=remove, inplace=True)

# %%
df.columns
# Out:
# Index(['fixture.id', 'fixture.date', 'fixture.venue.id', 'fixture.venue.name',
#        'fixture.venue.city', 'fixture.status.short', 'league.id',
#        'league.name', 'league.country', 'league.season', 'league.round',
#        'teams.home.id', 'teams.home.name', 'teams.away.id', 'teams.away.name',
#        'goals.home', 'goals.away', 'score.halftime.home',
#        'score.halftime.away', 'score.extratime.home', 'score.extratime.away',
#        'score.penalty.home', 'score.penalty.away'],
#       dtype='object')
